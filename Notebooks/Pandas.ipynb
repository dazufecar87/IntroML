# %%
import pandas as pd

# %%
series = pd.Series([5, 10, 15, 20, 25])
series
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# 4    25
# dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
series[3]
# Out:
# 20

# %%
cad = pd.Series(['p','l','a','t','z','i'])
cad
# Out:
# 0    p
# 1    l
# 2    a
# 3    t
# 4    z
# 5    i
# dtype: object

# %%
lst = ['Hola','mundo','robotico']
df = pd.DataFrame(lst)
print(df)
# Out:
#           0
# 0      Hola
# 1     mundo
# 2  robotico

# %%
# Nos crea como una tabla de SQL o excel
data = {'Nombre' : ['Juan', 'Ana', 'Jose', 'Arturo'],
        'Edad' : [25, 18, 23, 27], 
        'Pais' : ['MX', 'CO', 'BR', 'CO']}
df = pd.DataFrame(data)
df
# Out:
#    Nombre  Edad Pais
# 0    Juan    25   MX
# 1     Ana    18   CO
# 2    Jose    23   BR
# 3  Arturo    27   CO

# %%
# Imprimir dos columnas de esta estructura
print(df[['Nombre','Pais']])
# Out:
#    Nombre Pais
# 0    Juan   MX
# 1     Ana   CO
# 2    Jose   BR
# 3  Arturo   CO

# %%
# Leer un archivo csv y ver los primeros 5 elementos
data = pd.read_csv('canciones-2018.csv')
data.head(5)
# Out:
#                       id  ... time_signature
# 0  6DCZcSspjsKoFjzjrWoCd  ...            4.0
# 1  3ee8Jmje8o58CHK66QrVC  ...            4.0
# 2  0e7ipj03S05BNilyu5bRz  ...            4.0
# 3  3swc6WTsr7rl9DqQKQA55  ...            4.0
# 4  2G7V7zsVDxg1yRsu7Ew9R  ...            4.0
#
# [5 rows x 16 columns]

# %%
# guardar los artistas del dataframe
artista = data.artists
artista[5]
# Out:
# 'Post Malone'

# %%
# obtener informacion del elemento 15
info = data.iloc[15]
info
# Out:
# id                     3GCdLUSnKSMJhs4Tj6CV3
# name                All The Stars (with SZA)
# artists                       Kendrick Lamar
# danceability                           0.698
# energy                                 0.633
# key                                        8
# loudness                              -4.946
# mode                                       1
# speechiness                           0.0597
# acousticness                          0.0605
# instrumentalness                    0.000194
# liveness                              0.0926
# valence                                0.552
# tempo                                 96.924
# duration_ms                           232187
# time_signature                             4
# Name: 15, dtype: object

# %%
# Ver ultimos elementos
data.tail()
# Out:
#                        id  ... time_signature
# 95  630sXRhIcfwr2e4RdNtjK  ...            4.0
# 96  2xmrfQpmS2iJExTlklLoA  ...            4.0
# 97  5WvAo7DNuPRmk4APhdPzi  ...            5.0
# 98  1j4kHkkpqZRBwE0A4CN4Y  ...            4.0
# 99  3EPXxR3ImUwfayaurPi3c  ...            4.0
#
# [5 rows x 16 columns]

# %%
# ver la amplitud del archivo
data.shape
# Out:
# (100, 16)

# %%
# Para ver como estan definidas las columnas
data.columns
# Out:
# Index(['id', 'name', 'artists', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
# Ver informacion estadistica general de columna tempo
data['tempo'].describe()
# Out:
# count    100.000000
# mean     119.904180
# std       28.795984
# min       64.934000
# 25%       95.730750
# 50%      120.116000
# 75%      140.022750
# max      198.075000
# Name: tempo, dtype: float64

# %%
# Organizar de forma descendiente el dataframe
data.sort_index(axis = 1, ascending = False)
# Out:
#     valence  time_signature    tempo  ...  danceability       artists  acousticness
# 0    0.3570             4.0   77.169  ...         0.754         Drake        0.0332
# 1    0.4730             4.0   75.023  ...         0.740  XXXTENTACION        0.2580
# 2    0.1400             4.0  159.847  ...         0.587   Post Malone        0.1170
# 3    0.4390             4.0  140.124  ...         0.739   Post Malone        0.5800
# 4    0.3500             4.0   91.030  ...         0.835         Drake        0.0589
# ..      ...             ...      ...  ...           ...           ...           ...
# 95   0.2840             4.0  125.046  ...         0.684     Zac Efron        0.0716
# 96   0.3300             4.0  105.076  ...         0.638  Clean Bandit        0.2450
# 97   0.6390             5.0  135.702  ...         0.552     DJ Khaled        0.0733
# 98   0.0967             4.0  180.043  ...         0.258          ZAYN        0.1010
# ...

# %%
filtered_data = data.loc[:,['artists','name','danceability','duration_ms']]
filtered_data.sort_values(by = ['artists','duration_ms'], inplace = True)
filtered_data
# Out:
#                 artists  ... duration_ms
# 23  5 Seconds of Summer  ...    203418.0
# 55              6ix9ine  ...    179405.0
# 88               Anitta  ...    193456.0
# 60           Anne-Marie  ...    186987.0
# 65        Ariana Grande  ...    197547.0
# ..                  ...  ...         ...
# 1          XXXTENTACION  ...    166606.0
# 98                 ZAYN  ...    239000.0
# 95            Zac Efron  ...    217440.0
# 14                 Zedd  ...    184732.0
# 35         benny blanco  ...    173800.0
#
# [100 rows x 4 columns]

# %%
filtered_data = (data[['artists','name','danceability','duration_ms']]
                 .sort_values(by = ['artists','duration_ms']))
filtered_data
# Out:
#                 artists  ... duration_ms
# 23  5 Seconds of Summer  ...    203418.0
# 55              6ix9ine  ...    179405.0
# 88               Anitta  ...    193456.0
# 60           Anne-Marie  ...    186987.0
# 65        Ariana Grande  ...    197547.0
# ..                  ...  ...         ...
# 1          XXXTENTACION  ...    166606.0
# 98                 ZAYN  ...    239000.0
# 95            Zac Efron  ...    217440.0
# 14                 Zedd  ...    184732.0
# 35         benny blanco  ...    173800.0
#
# [100 rows x 4 columns]

# %%
filtered_data = data[['artists','name','danceability','duration_ms']]
filtered_data.sort_index(by = ['artists','duration_ms'], axis = 0)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)
#                 artists  ... duration_ms
# 23  5 Seconds of Summer  ...    203418.0
# 55              6ix9ine  ...    179405.0
# 88               Anitta  ...    193456.0
# 60           Anne-Marie  ...    186987.0
# 65        Ariana Grande  ...    197547.0
# ..                  ...  ...         ...
# 1          XXXTENTACION  ...    166606.0
# 98                 ZAYN  ...    239000.0
# 95            Zac Efron  ...    217440.0
# 14                 Zedd  ...    184732.0
# 35         benny blanco  ...    173800.0
#
# [100 rows x 4 columns]
