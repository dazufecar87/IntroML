# %%
import pandas as pd
from sklearn.mixture import GaussianMixture
from sklearn.manifold import SpectralEmbedding
from sklearn import datasets
from sklearn import metrics
import seaborn as sns

# %%
wines = datasets.load_wine()
X_wines = wines.data
Y_wines = wines.target
xw = pd.DataFrame(X_wines, columns = ['Alcohol', 'Malic Acid', 'Ash', 'Alcalinity of Ash', 'Magnesium', 
                                      'Total Phenols', 'Flavanoids', 'Nonflavanoid Phenols', 'Proanthocyanins', 
                                      'Colour Intensity', 'Hue', 'OD280/OD315 of diluted wines', 'Proline'])
yw = pd.DataFrame(Y_wines, columns = ['Target'])
xw.head(5)
# Out:
#    Alcohol  Malic Acid   Ash  ...   Hue  OD280/OD315 of diluted wines  Proline
# 0    14.23        1.71  2.43  ...  1.04                          3.92   1065.0
# 1    13.20        1.78  2.14  ...  1.05                          3.40   1050.0
# 2    13.16        2.36  2.67  ...  1.03                          3.17   1185.0
# 3    14.37        1.95  2.50  ...  0.86                          3.45   1480.0
# 4    13.24        2.59  2.87  ...  1.04                          2.93    735.0
#
# [5 rows x 13 columns]

# %%
se = SpectralEmbedding(n_components=13)
xw_se = se.fit_transform(xw)
xw_se_df = pd.DataFrame(xw_se)

for i in range(1, 11):
    gmm = GaussianMixture(n_components=i, max_iter=1000)
    gmm.fit(xw_se_df)
    yw_gmm = gmm.predict(xw_se_df)
    accuracy =  metrics.adjusted_rand_score(Y_wines, yw_gmm)
    print(f'numero de n_clusters: {i} accurracy {accuracy}')
# Out:
# numero de n_clusters: 1 accurracy 0.0
# numero de n_clusters: 2 accurracy 0.01724148271621445
# numero de n_clusters: 3 accurracy 0.41656142581226974
# numero de n_clusters: 4 accurracy 0.09177772071734364
# numero de n_clusters: 5 accurracy 0.130034146685391
# numero de n_clusters: 6 accurracy 0.15278489134652393
# numero de n_clusters: 7 accurracy 0.16770980570918748
# numero de n_clusters: 8 accurracy 0.17233284167996035
# numero de n_clusters: 9 accurracy 0.12927470794758997
# numero de n_clusters: 10 accurracy 0.1779309137994222
